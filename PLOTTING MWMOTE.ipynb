# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Data Diabetes**

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/Data After Processing/Data Diabetes.csv')

# menentukan kelas minoritas dan kelas mayoritas
target_column = 'Outcome'
class_counts = df[target_column].value_counts()

plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class Outcome Data Diabetes')
plt.show()

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']
plt.scatter(X.loc[y == 0, "Age"], X.loc[y == 0, "BMI"], label="500 Data Mayoritas")
plt.scatter(X.loc[y == 1, "Age"], X.loc[y == 1, "BMI"], label="268 Data Minoritas")
plt.title("Data Diabetes Sebelum Oversampling")
plt.legend()
plt.show()

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/MWMOTE/MWMOTE Data Diabetes.csv')
# menentukan kelas minoritas dan kelas mayoritas
target_column = 'Outcome'
class_counts = df[target_column].value_counts()

plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class Outcome Data Diabetes')
plt.show()

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']
plt.scatter(X.loc[y == 0, "Age"], X.loc[y == 0, "BMI"], label="500 Data Mayoritas")
plt.scatter(X.loc[y == 1, "Age"], X.loc[y == 1, "BMI"], label="500 Data Minoritas")
plt.title("Data Diabetes Sesudah Oversampling")
plt.legend()
plt.show()

# %% [markdown]
# ## **Data Bank Turnover**

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/Data After Processing/Data Bank Turnover.csv')

# menentukan kelas minoritas dan kelas mayoritas
target_column = 'Exited'
class_counts = df[target_column].value_counts()


plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class Exited Bank Turnover')
plt.show()

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']
plt.scatter(X.loc[y == 0, "Age"], X.loc[y == 0, "CreditScore"], label="7.963 Data Mayoritas")
plt.scatter(X.loc[y == 1, "Age"], X.loc[y == 1, "CreditScore"], label="2.037 Data Minoritas")
plt.title("Data Bank Turnover Sebelum Oversampling")
plt.legend()
plt.show()

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/MWMOTE/MWMOTE Data Bank Turnover.csv')

# menentukan kelas minoritas dan kelas mayoritas
target_column = 'Exited'
class_counts = df[target_column].value_counts()


plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class Exited Bank Turnover')
plt.show()

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']
plt.scatter(X.loc[y == 0, "Age"], X.loc[y == 0, "CreditScore"], label="7.963 Data Mayoritas")
plt.scatter(X.loc[y == 1, "Age"], X.loc[y == 1, "CreditScore"], label="7.963 Data Minoritas")
plt.title("Data Bank Turnover Sesudah Oversampling")
plt.legend()
plt.show()

# %% [markdown]
# ## **Data Stroke**

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/Data After Processing/Data Stroke.csv')

# menentukan kelas minoritas dan kelas mayoritas
target_column = 'stroke'
class_counts = df[target_column].value_counts()


plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class stroke Data Stroke')
plt.show()

# %%
X = df.drop('stroke', axis=1)
y = df['stroke']
plt.scatter(X.loc[y == 0, "avg_glucose_level"], X.loc[y == 0, "bmi"], label="4.861 Data Mayoritas")
plt.scatter(X.loc[y == 1, "avg_glucose_level"], X.loc[y == 1, "bmi"], label="249 Data Minoritas")
plt.title("Data Stroke Sebelum Oversampling")
plt.legend()
plt.show()

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/MWMOTE/MWMOTE Data Stroke.csv')

# menentukan kelas minoritas dan kelas mayoritas
target_column = 'stroke'
class_counts = df[target_column].value_counts()


plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class stroke Data Stroke')
plt.show()

# %%
X = df.drop('stroke', axis=1)
y = df['stroke']
plt.scatter(X.loc[y == 0, "avg_glucose_level"], X.loc[y == 0, "bmi"], label="4.861 Data Mayoritas")
plt.scatter(X.loc[y == 1, "avg_glucose_level"], X.loc[y == 1, "bmi"], label="4.861 Data Minoritas")
plt.title("Data Stroke Sesudah Oversampling")
plt.legend()
plt.show()

# %% [markdown]
# ## **Data Credit Card**

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/Data After Processing/Data Credit Card.csv')

# menentukan kelas minoritas dan kelas mayoritas
target_column = 'Class'
class_counts = df[target_column].value_counts()

plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class Data Credit Card')
plt.show()

# %%
X = df.drop('Class', axis=1)
y = df['Class']
plt.scatter(X.loc[y == 0, "V1"], X.loc[y == 0, "V28"], label="284.315 Data Mayoritas")
plt.scatter(X.loc[y == 1, "V1"], X.loc[y == 1, "V28"], label="492 Data Minoritas")
plt.title("Data Credit Card Sebelum Oversampling")
plt.legend()
plt.show()

# %%
# memuat dataset dari file CSV
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Desktop/SEMINAR HASIL/Code TA/MWMOTE/MWMOTE Data Credit Card.csv')

# menentukan kelas minoritas dan kelas mayoritas
target_column = 'Class'
class_counts = df[target_column].value_counts()

plt.bar(class_counts.index, class_counts.values,color=['blue','orange'])
plt.xticks(class_counts.index)
plt.xlabel('Kelas')
plt.ylabel('Jumlah')
plt.title('Class Data Credit Card')
plt.show()

# %%
X = df.drop('Class', axis=1)
y = df['Class']
plt.scatter(X.loc[y == 0, "V1"], X.loc[y == 0, "V28"], label="284.315 Data Mayoritas")
plt.scatter(X.loc[y == 1, "V1"], X.loc[y == 1, "V28"], label="284.315 Data Minoritas")
plt.title("Data Credit Card Sesudah Oversampling")
plt.legend()
plt.show()

# %%
y.value_counts()
# Out:
# 0.0    284315
# 1.0    284315
# Name: Class, dtype: int64
